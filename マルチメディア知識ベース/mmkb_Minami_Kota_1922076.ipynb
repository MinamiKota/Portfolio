# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# corging: utf8
import sys
import random
import math
import copy
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/content/gdrive/MyDrive/1/coral2.jpg")
img2 = cv2.imread("/content/gdrive/MyDrive/1/coral2.jpg")
img_3 = cv2.imread("/content/gdrive/MyDrive/1/coral2.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_3 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
threshold = 180
ret, img = cv2.threshold(img, threshold, 255, cv2.THRESH_BINARY)
plt.gray()
plt.imshow(img)

# %%
img = cv2.Canny(img, 70, 190)

plt.gray()
plt.imshow(img)
